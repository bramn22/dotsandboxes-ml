# %%
import agent.MCTS as mcts_
import numpy as np
from agent.MCTS.mcts import Node
from agent.MCTS.mcts import MCTS
import copy
# Out:
# Start of selection.
# End of selection.
# Start of expansion.
# (0, 0, 'h')
# (0, 0, 'v')
# (0, 1, 'v')
# (1, 0, 'h')
# End of expansion.
# Start of simulation.
# Node: player-2, wr-0, vr-0, free-moves-[(0, 0, 'h'), (0, 0, 'v'), (1, 0, 'h')]
# Player: 2
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# (0, 0, 'v')
# (0, 1, 'v')
# (1, 0, 'h')
# End of expansion.
# Start of simulation.
# Node: player-1, wr-0, vr-0, free-moves-[(0, 1, 'v'), (1, 0, 'h')]
# Player: 2
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# (0, 0, 'h')
# (0, 1, 'v')
# (1, 0, 'h')
# End of expansion.
# Start of simulation.
# Node: player-1, wr-0, vr-0, free-moves-[(0, 0, 'h'), (0, 1, 'v')]
# Player: 2
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# (0, 0, 'h')
# (0, 0, 'v')
# (0, 1, 'v')
# End of expansion.
# Start of simulation.
# Node: player-1, wr-0, vr-0, free-moves-[(0, 0, 'v'), (0, 1, 'v')]
# Player: 2
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# (0, 0, 'v')
# (1, 0, 'h')
# End of expansion.
# Start of simulation.
# Node: player-2, wr-0, vr-0, free-moves-[(0, 0, 'v')]
# Player: 2
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# (0, 1, 'v')
# (1, 0, 'h')
# End of expansion.
# Start of simulation.
# Node: player-2, wr-0, vr-0, free-moves-[(0, 1, 'v')]
# Player: 2
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# (0, 0, 'h')
# (0, 1, 'v')
# End of expansion.
# Start of simulation.
# Node: player-2, wr-0, vr-0, free-moves-[(0, 0, 'h')]
# Player: 2
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# (0, 0, 'v')
# (0, 1, 'v')
# End of expansion.
# Start of simulation.
# Node: player-2, wr-0, vr-0, free-moves-[(0, 1, 'v')]
# Player: 2
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# (0, 0, 'h')
# (1, 0, 'h')
# End of expansion.
# Start of simulation.
# Node: player-2, wr-0, vr-0, free-moves-[(0, 0, 'h')]
# Player: 2
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# (0, 0, 'h')
# (0, 0, 'v')
# End of expansion.
# Start of simulation.
# Node: player-2, wr-0, vr-0, free-moves-[(0, 0, 'h')]
# Player: 2
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# (1, 0, 'h')
# End of expansion.
# Start of simulation.
# Node: player-2, wr-0, vr-0, free-moves-[]
# Player: 2
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# (1, 0, 'h')
# End of expansion.
# Start of simulation.
# Node: player-2, wr-0, vr-0, free-moves-[]
# Player: 2
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# (1, 0, 'h')
# End of expansion.
# Start of simulation.
# Node: player-2, wr-0, vr-0, free-moves-[]
# Player: 2
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# (0, 1, 'v')
# End of expansion.
# Start of simulation.
# Node: player-2, wr-0, vr-0, free-moves-[]
# Player: 2
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# (0, 0, 'v')
# End of expansion.
# Start of simulation.
# Node: player-2, wr-0, vr-0, free-moves-[]
# Player: 2
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# (0, 0, 'v')
# End of expansion.
# Start of simulation.
# Node: player-2, wr-0, vr-0, free-moves-[]
# Player: 2
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 2
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 2
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 2
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 2
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 2
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 2
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 2
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 2
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 2
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 2
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 2
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 2
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# ...
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x104147F0>, <agent.MCTS.mcts.Node object at 0x10414710>, <agent.MCTS.mcts.Node object at 0x10414550>, <agent.MCTS.mcts.Node object at 0x104148D0>]
# End of backpropagation.
# Node: player-1, wr-454, vr-500, free-moves-[(0, 0, 'h'), (0, 0, 'v'), (0, 1, 'v'), (1, 0, 'h')]

# %%
mcts = MCTS()
player = 1
board = [
    [{"v": 0, "h": 0}, {"v": 0, "h": 0}],
    [{"v": 0, "h": 0}, {"v": 0, "h": 0}]]
free_moves = [(0, 0, "h"), (0, 0, "v"),
              (0, 1, "v"),
              (1, 0, "h")]
points = [0, 0]
root = Node(None, board, free_moves, player, points)
index = 0
while index < 500:
    index = index + 1
    root_ = self.selection(root)
    self.expansion(root_)
    child, winingP = self.simulation(root_)
    self.backpropagation(child, winingP)
# Out:
# Start of selection.
# End of selection.
# Start of expansion.
# (0, 0, 'h')
# (0, 0, 'v')
# (0, 1, 'v')
# (1, 0, 'h')
# End of expansion.
# Start of simulation.
# Node: player-2, wr-0, vr-0, free-moves-[(0, 0, 'h'), (0, 1, 'v'), (1, 0, 'h')]
# Player: 2
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# (0, 0, 'v')
# (0, 1, 'v')
# (1, 0, 'h')
# End of expansion.
# Start of simulation.
# Node: player-1, wr-0, vr-0, free-moves-[(0, 1, 'v'), (1, 0, 'h')]
# Player: 2
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# (0, 0, 'h')
# (0, 0, 'v')
# (1, 0, 'h')
# End of expansion.
# Start of simulation.
# Node: player-1, wr-0, vr-0, free-moves-[(0, 0, 'h'), (0, 0, 'v')]
# Player: 2
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# (0, 0, 'h')
# (0, 0, 'v')
# (0, 1, 'v')
# End of expansion.
# Start of simulation.
# Node: player-1, wr-0, vr-0, free-moves-[(0, 0, 'h'), (0, 1, 'v')]
# Player: 2
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# (0, 0, 'v')
# (1, 0, 'h')
# End of expansion.
# Start of simulation.
# Node: player-2, wr-0, vr-0, free-moves-[(0, 0, 'v')]
# Player: 2
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# (0, 0, 'v')
# (1, 0, 'h')
# End of expansion.
# Start of simulation.
# Node: player-2, wr-0, vr-0, free-moves-[(1, 0, 'h')]
# Player: 2
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# (0, 0, 'v')
# (0, 1, 'v')
# End of expansion.
# Start of simulation.
# Node: player-2, wr-0, vr-0, free-moves-[(0, 1, 'v')]
# Player: 2
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# (0, 0, 'v')
# (0, 1, 'v')
# End of expansion.
# Start of simulation.
# Node: player-2, wr-0, vr-0, free-moves-[(0, 1, 'v')]
# Player: 2
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# (0, 0, 'h')
# (1, 0, 'h')
# End of expansion.
# Start of simulation.
# Node: player-2, wr-0, vr-0, free-moves-[(1, 0, 'h')]
# Player: 2
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# (0, 0, 'h')
# (0, 0, 'v')
# End of expansion.
# Start of simulation.
# Node: player-2, wr-0, vr-0, free-moves-[(0, 0, 'v')]
# Player: 2
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# (0, 0, 'v')
# End of expansion.
# Start of simulation.
# Node: player-2, wr-0, vr-0, free-moves-[]
# Player: 2
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# (0, 0, 'v')
# End of expansion.
# Start of simulation.
# Node: player-2, wr-0, vr-0, free-moves-[]
# Player: 2
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# (0, 0, 'h')
# End of expansion.
# Start of simulation.
# Node: player-2, wr-0, vr-0, free-moves-[]
# Player: 2
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# (0, 0, 'h')
# End of expansion.
# Start of simulation.
# Node: player-2, wr-0, vr-0, free-moves-[]
# Player: 2
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# (1, 0, 'h')
# End of expansion.
# Start of simulation.
# Node: player-2, wr-0, vr-0, free-moves-[]
# Player: 2
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# (0, 0, 'v')
# End of expansion.
# Start of simulation.
# Node: player-2, wr-0, vr-0, free-moves-[]
# Player: 2
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 2
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 2
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 2
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 2
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 2
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 2
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 2
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 2
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 2
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 2
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 2
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 2
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# ...
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Start of selection.
# End of selection.
# Start of expansion.
# End of expansion.
# Start of simulation.
# Player: 1
# End of simulation.
# Start of backpropagation.
# [<agent.MCTS.mcts.Node object at 0x10414BB0>, <agent.MCTS.mcts.Node object at 0x10414C90>, <agent.MCTS.mcts.Node object at 0x10414D30>, <agent.MCTS.mcts.Node object at 0x10414DF0>]
# End of backpropagation.
# Node: player-1, wr-454, vr-500, free-moves-[(0, 0, 'h'), (0, 0, 'v'), (0, 1, 'v'), (1, 0, 'h')]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-fdd0a7dfffef> in <module>()
#      12 while index < 500:
#      13     index = index + 1
# ---> 14     root_ = self.selection(root)
#      15     self.expansion(root_)
#      16     child, winingP = self.simulation(root_)
#
# NameError: name 'self' is not defined

# %%
print(root)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-b3102c118526> in <module>()
# ----> 1 print(root)
#
# NameError: name 'root' is not defined

# %%
mcts.expansion(node)
# Out:
# Start of expansion.
# (0, 0, 'h')
# (0, 0, 'v')
# (0, 1, 'h')
# (0, 1, 'v')
# (1, 0, 'h')
# (1, 0, 'v')
# (1, 1, 'h')
# (1, 1, 'v')
# End of expansion.

# %%
child, winningPlayer = mcts.simulation(node)
print(child,winningPlayer)
# Out:
# Start of simulation.
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-14-ed6ad8cb5530> in <module>()
# ----> 1 child, winningPlayer = mcts.simulation(node)
#       2 print(child,winningPlayer)
#
# E:\KUL\2de_jaar_Master\Semester 2\MLProject\PythonMCTS\agent\MCTS\mcts.py in simulation(self, node)
#      53         # pick node with strategy
#      54         child = self.select_random_child(node.children)
# ---> 55         print(child)
#      56         winning_player = self.random_playout(child)
#      57         print("End of simulation.")
#
# E:\KUL\2de_jaar_Master\Semester 2\MLProject\PythonMCTS\agent\MCTS\mcts.py in random_playout(self, node)
#      75             move_idx = self.select_random_idx_from_list(moves)
#      76             move = moves[move_idx]
# ---> 77             # evaluate move using take_action (returns results , next player)
#      78             cur_player = eval.user_action(move, cur_player, board, points) #TODO: check if board and points has been adjusted
#      79         #   take action on random move from moves
#
# E:\KUL\2de_jaar_Master\Semester 2\MLProject\PythonMCTS\agent\MCTS\board_evaluator.py in user_action(move, cur_player, cells, points)
#      25         if r < nb_rows:
#      26             if cells[r][c]["v"] != 0 \
# ---> 27                 and cells[r][c + 1]["v"] != 0 \
#      28                 and cells[r][c]["h"] != 0 \
#      29                 and cells[r + 1][c]["h"] != 0:
#
# IndexError: list index out of range
